# %%
pip install dataprep
# Out:
# Collecting dataprep
#   Downloading dataprep-0.4.5-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 75.9 MB/s eta 0:00:00:00:0100:01
# Collecting rapidfuzz<3.0.0,>=2.1.2
#   Downloading rapidfuzz-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 77.1 MB/s eta 0:00:00:00:01
# Collecting flask_cors<4.0.0,>=3.0.10
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting jsonpath-ng<2.0,>=1.5
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting python-crfsuite==0.9.8
#   Downloading python_crfsuite-0.9.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.8 MB/s eta 0:00:00
# Collecting pydantic<2.0,>=1.6
#   Downloading pydantic-1.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 81.5 MB/s eta 0:00:00:00:01
# Collecting jinja2<3.1,>=3.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.6/133.6 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0,>=4.48 in /opt/conda/lib/python3.10/site-packages (from dataprep) (4.64.1)
# Collecting metaphone<0.7,>=0.6
#   Downloading Metaphone-0.6.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas<2.0,>=1.1 in /opt/conda/lib/python3.10/site-packages (from dataprep) (1.5.1)
# Collecting flask<3,>=2
#   Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 18.0 MB/s eta 0:00:00
# Collecting varname<0.9.0,>=0.8.1
#   Downloading varname-0.8.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy<2.0,>=1.21 in /opt/conda/lib/python3.10/site-packages (from dataprep) (1.23.4)
# Requirement already satisfied: bokeh<3,>=2 in /opt/conda/lib/python3.10/site-packages (from dataprep) (2.4.3)
# Collecting sqlalchemy==1.3.24
#   Downloading SQLAlchemy-1.3.24.tar.gz (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 81.1 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dask[array,dataframe,delayed]>=2022.3.0 in /opt/conda/lib/python3.10/site-packages (from dataprep) (2022.10.0)
# Collecting pydot<2.0.0,>=1.4.2
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting regex<2022.0.0,>=2021.8.3
#   Downloading regex-2021.11.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (764 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.0/764.0 kB 53.8 MB/s eta 0:00:00
# Collecting ipywidgets<8.0,>=7.5
#   Downloading ipywidgets-7.7.5-py2.py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 20.9 MB/s eta 0:00:00
# Collecting aiohttp<4.0,>=3.6
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 66.6 MB/s eta 0:00:00
# Collecting nltk<4.0.0,>=3.6.7
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 73.6 MB/s eta 0:00:00
# Collecting wordcloud<2.0,>=1.8
#   Downloading wordcloud-1.9.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (455 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 kB 47.8 MB/s eta 0:00:00
# Collecting python-stdnum<2.0,>=1.16
#   Downloading python_stdnum-1.18-py2.py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2.0,>=1.8 in /opt/conda/lib/python3.10/site-packages (from dataprep) (1.9.3)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 22.3 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 37.6 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 20.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->dataprep) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.1.1)
# Requirement already satisfied: pillow>=7.1.0 in /opt/conda/lib/python3.10/site-packages (from bokeh<3,>=2->dataprep) (9.2.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /opt/conda/lib/python3.10/site-packages (from bokeh<3,>=2->dataprep) (4.4.0)
# Requirement already satisfied: tornado>=5.1 in /opt/conda/lib/python3.10/site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: packaging>=16.8 in /opt/conda/lib/python3.10/site-packages (from bokeh<3,>=2->dataprep) (21.3)
# Requirement already satisfied: PyYAML>=3.10 in /opt/conda/lib/python3.10/site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: fsspec>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2022.10.0)
# Requirement already satisfied: partd>=0.3.10 in /opt/conda/lib/python3.10/site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /opt/conda/lib/python3.10/site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.12.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2.2.0)
# Collecting flask<3,>=2
#   Downloading Flask-2.3.1-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 18.0 MB/s eta 0:00:00
#   Downloading Flask-2.3.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 17.3 MB/s eta 0:00:00
#   Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 18.4 MB/s eta 0:00:00
# Collecting Werkzeug>=2.2.2
#   Downloading Werkzeug-2.3.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 29.8 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: click>=8.0 in /opt/conda/lib/python3.10/site-packages (from flask<3,>=2->dataprep) (8.1.3)
# Requirement already satisfied: Six in /opt/conda/lib/python3.10/site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: ipython>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (8.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.16.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Collecting widgetsnbextension~=3.6.4
#   Downloading widgetsnbextension-3.6.4-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.7 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.5.0)
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Downloading jupyterlab_widgets-1.1.4-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 37.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2<3.1,>=3.0->dataprep) (2.1.1)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (5.1.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.0,>=1.1->dataprep) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.0,>=1.1->dataprep) (2022.5)
# Requirement already satisfied: pyparsing>=2.1.4 in /opt/conda/lib/python3.10/site-packages (from pydot<2.0.0,>=1.4.2->dataprep) (3.0.9)
# Requirement already satisfied: pure_eval<1.0.0 in /opt/conda/lib/python3.10/site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.2.2)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from varname<0.9.0,>=0.8.1->dataprep) (2.0.8)
# Collecting executing<0.9.0,>=0.8.3
#   Downloading executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.6.3)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (24.0.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (5.9.3)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.6)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.31)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.13.0)
# Requirement already satisfied: locket in /opt/conda/lib/python3.10/site-packages (from partd>=0.3.10->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (6.5.1)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (3.4)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.0.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (4.11.1)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (7.2.2)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (5.7.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (21.3.0)
# Requirement already satisfied: nbclassic==0.4.5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.4.5)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.16.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.15.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.21.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.2.2)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (5.0.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (2.0.4)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (4.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.18.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (3.6.2)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.4.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (2.21)
# Building wheels for collected packages: sqlalchemy, metaphone
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.24-cp310-cp310-linux_x86_64.whl size=1220173 sha256=ddf1172830125b05f90c159a025c5595e9dc934666bb04a8540fccf36292abc9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/c8/47/30/58f5319511b287d4cf145aa940abec1e7824bba5bd8f4de0b3
#   Building wheel for metaphone (setup.py) ... done
#   Created wheel for metaphone: filename=Metaphone-0.6-py3-none-any.whl size=13901 sha256=a65417e9ae9bc98706d5dbd4bbca1167b5bbed74c55cce84ac96ad0ebd7fa564
#   Stored in directory: /home/jovyan/.cache/pip/wheels/91/df/55/49d1d0c09e7262d3e6a8ff232f4fb28380426e0db4169cea36
# Successfully built sqlalchemy metaphone
# Installing collected packages: regex, python-stdnum, python-crfsuite, ply, metaphone, executing, Werkzeug, sqlalchemy, rapidfuzz, pydot, pydantic, nltk, multidict, jupyterlab-widgets, jsonpath-ng, jinja2, itsdangerous, frozenlist, async-timeout, yarl, varname, flask, aiosignal, wordcloud, flask_cors, aiohttp, widgetsnbextension, ipywidgets, dataprep
#   Attempting uninstall: executing
#     Found existing installation: executing 1.1.1
#     Uninstalling executing-1.1.1:
#       Successfully uninstalled executing-1.1.1
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.42
#     Uninstalling SQLAlchemy-1.4.42:
#       Successfully uninstalled SQLAlchemy-1.4.42
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.3
#     Uninstalling jupyterlab-widgets-3.0.3:
#       Successfully uninstalled jupyterlab-widgets-3.0.3
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.3
#     Uninstalling widgetsnbextension-4.0.3:
#       Successfully uninstalled widgetsnbextension-4.0.3
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.0.2
#     Uninstalling ipywidgets-8.0.2:
#       Successfully uninstalled ipywidgets-8.0.2
# Successfully installed Werkzeug-2.3.4 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 dataprep-0.4.5 executing-0.8.3 flask-2.2.5 flask_cors-3.0.10 frozenlist-1.3.3 ipywidgets-7.7.5 itsdangerous-2.1.2 jinja2-3.0.3 jsonpath-ng-1.5.3 jupyterlab-widgets-1.1.4 metaphone-0.6 multidict-6.0.4 nltk-3.8.1 ply-3.11 pydantic-1.10.7 pydot-1.4.2 python-crfsuite-0.9.8 python-stdnum-1.18 rapidfuzz-2.15.1 regex-2021.11.10 sqlalchemy-1.3.24 varname-0.8.3 widgetsnbextension-3.6.4 wordcloud-1.9.1.1 yarl-1.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_playstore.csv")

# %%
from dataprep.eda import create_report

create_report(df).show_browser()
# Out:
#   0%|          | 0/2087 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))

# %%
from dataprep.datasets import load_dataset
from dataprep.eda import create_report
df = load_dataset("titanic")
create_report(df).show_browser()
# Out:
#   0%|          | 0/1420 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /opt/conda/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
